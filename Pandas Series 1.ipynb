# %% [markdown]
# ### What is Pandas Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool, built on top of the Python programming language. https://pandas.pydata.org/about/index.html
# ### Pandas Series A Pandas Series is like a column in a table. It is a 1-D array holding data of any type.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Series from lists

# %%
#String
country = ["india","china","nepal","USA"]
pd.Series(country)
# Out:
# 0    india
# 1    china
# 2    nepal
# 3      USA
# dtype: object

# %%
# Integer
runs = [1,23,34,323,323]
pd.Series(runs)
# Out:
# 0      1
# 1     23
# 2     34
# 3    323
# 4    323
# dtype: int64

# %%
#Custom Index
marks = [23,23,12,43]
sub = ["maths","english","hindi","science"]
a = pd.Series(marks,index = sub)
a
# Out:
# maths      23
# english    23
# hindi      12
# science    43
# dtype: int64

# %%
# Setting a name
marks = pd.Series(marks,index = sub,name = 'Divyansh ke marks')
marks
# Out:
# maths      23
# english    23
# hindi      12
# science    43
# Name: Divyansh ke marks, dtype: int64

# %%
m = {"maths":44,'English':99,"hindi":89}
pd.Series(m)
# Out:
# maths      44
# English    99
# hindi      89
# dtype: int64

# %% [markdown]
# ## Series Attributes

# %%
# Size (gives the size of the series)
marks.size
# Out:
# 4

# %%
#dtype
marks.dtype
# Out:
# dtype('int64')

# %%
marks.name
# Out:
# 'Divyansh ke marks'

# %%
#is_unique
pd.Series([1,1,2,3,4,5]).is_unique  #False because of two "1"
# Out:
# False

# %%
# index
marks.index
# Out:
# Index(['maths', 'english', 'hindi', 'science'], dtype='object')

# %%
# values
marks.values
# Out:
# array([23, 23, 12, 43])

# %% [markdown]
# # Series using read_csv

# %%
vk = pd.read_csv(r'C:\Users\divya\Downloads\virat_kohli_ipl_runs.csv',index_col='match_no').squeeze()
vk
# Out:
# match_no
# 1       43
# 2      116
# 3       40
# 4       45
# 5        7
#       ...
# 263     70
# 264     95
# 265    114
# 266    117
# 267      8
# Name: runs, Length: 267, dtype: int64

# %%
m = pd.read_csv(r'C:\Users\divya\Downloads\bollywood_movies_250_rows.csv').squeeze()
m
# Out:
#                   Movie      Lead Actor
# 0         Prem Ka Safar     Salman Khan
# 1     Zindagi Ki Kahani   Kartik Aaryan
# 2       Raaz Ek Dastaan   Shahid Kapoor
# 3       Dosti Ki Kahani   Kartik Aaryan
# 4          Dil Reloaded    Tiger Shroff
# ..                  ...             ...
# 245   Aashiqui Ka Safar    Tiger Shroff
# 246        Ishq Forever     Salman Khan
# 247  Bandhan Ek Dastaan  Shah Rukh Khan
# 248          Prem Story      Ajay Devgn
# 249  Aashiqui Ki Kahani   Shahid Kapoor
#
# [250 rows x 2 columns]

# %% [markdown]
# ![Screenshot 2026-03-04 213451.png](attachment:c59ad9dd-c14a-4437-ba52-c607b02e8bcf.png)

# %%
type(m['Lead Actor']),type(m)
# Out:
# (pandas.core.series.Series, pandas.core.frame.DataFrame)

# %% [markdown]
# # Series Methods

# %%
# head and tail
vk.head()  # it gives the top 5 rows
vk.head(7)  # or you can give index
# Out:
# match_no
# 1     43
# 2    116
# 3     40
# 4     45
# 5      7
# 6     75
# 7    100
# Name: runs, dtype: int64

# %%
vk.tail()     # it gives the last 5 rows
# Out:
# match_no
# 263     70
# 264     95
# 265    114
# 266    117
# 267      8
# Name: runs, dtype: int64

# %%
# sample
vk.sample(7)   # it will give randomly 7 rows
# Out:
# match_no
# 132    76
# 114     9
# 9      72
# 213    62
# 72     24
# 136    36
# 101    72
# Name: runs, dtype: int64

# %%
# value_counts:
m['Lead Actor'].value_counts()
# Out:
# Lead Actor
# Sidharth Malhotra     17
# Kartik Aaryan         17
# Ajay Devgn            17
# Shahid Kapoor         16
# Tiger Shroff          16
# Saif Ali Khan         16
# Amitabh Bachchan      15
# Rajkummar Rao         14
# Salman Khan           13
# Anil Kapoor           13
# Varun Dhawan          12
# Shah Rukh Khan        12
# Ayushmann Khurrana    12
# Akshay Kumar          12
# R. Madhavan           10
# Arjun Kapoor           9
# Ranbir Kapoor          9
# Aamir Khan             8
# Ranveer Singh          7
# Hrithik Roshan         5
# Name: count, dtype: int64

# %%
# sort_values
vk.sort_values(ascending=False).head(1).values[0]  #IT WILL NOT CHANGE THE ORIGINAL VK VARIABLE
# Out:
# np.int64(120)

# %% [markdown]
# ## TO CHANGE IT PERMANENTLY USE:

# %%
#vk.sort_values(inplace = True)  # IT WILL CHANGE THE ORIGINAL VK

# %%
m['Movie'].sort_index(ascending=False)   #it will sort the index of m
# Out:
# 249    Aashiqui Ki Kahani
# 248            Prem Story
# 247    Bandhan Ek Dastaan
# 246          Ishq Forever
# 245     Aashiqui Ka Safar
#               ...
# 4            Dil Reloaded
# 3         Dosti Ki Kahani
# 2         Raaz Ek Dastaan
# 1       Zindagi Ki Kahani
# 0           Prem Ka Safar
# Name: Movie, Length: 250, dtype: object

# %% [markdown]
# # Series maths Methods

# %%
# count   give the total no. of values excluding missing values
vk.count()
# Out:
# np.int64(267)

# %%
# sum  but it will include the null values
vk.sum()  # it will give the sum of runs
# Out:
# np.int64(16456)

# %%
vk.mean(),vk.median()
# Out:
# (np.float64(61.63295880149813), 66.0)

# %%
print(vk.mode())   # will give:index,    mode value
# Out:
# 0    4
# Name: runs, dtype: int64

# %%
vk.std(),vk.var(),vk.min(),vk.max()
# Out:
# (35.65551713430669, 1271.3159021148383, 0, 120)

# %%
#describe
vk.describe()  #IT WILL GIVE THE ALL BIODATA
# Out:
# count    267.000000
# mean      61.632959
# std       35.655517
# min        0.000000
# 25%       31.500000
# 50%       66.000000
# 75%       92.000000
# max      120.000000
# Name: runs, dtype: float64

# %%
m.describe()
# Out:
#                  Movie         Lead Actor
# count              250                250
# unique             101                 20
# top     Safar Ka Safar  Sidharth Malhotra
# freq                 6                 17

# %%
vk.product()  # it will give the product of all values
# Out:
# np.int64(0)

# %% [markdown]
# # Series Indexing

# %%
x = pd.Series([12,22,34,54,5,3,334,434,34,3])
x
# Out:
# 0     12
# 1     22
# 2     34
# 3     54
# 4      5
# 5      3
# 6    334
# 7    434
# 8     34
# 9      3
# dtype: int64

# %%
x[0]
# Out:
# np.int64(12)

# %%
x[-1]  #negative indexing doesn't work here
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[147], line 1
# ----> 1 x[-1]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:1133, in Series.__getitem__(self, key)
#    1130     return self._values[key]
#    1132 elif key_is_scalar:
# -> 1133     return self._get_value(key)
#    1135 # Convert generator to list before going through hashable part
#    1136 # (We will iterate through the generator there to check for slices)
#    1137 if is_iterator(key):
#
# ...

# %%
vk[5:16]
# Out:
# match_no
# 6      75
# 7     100
# 8     105
# 9      72
# 10     77
# 11     42
# 12     84
# 13     98
# 14     19
# 15    118
# 16     35
# Name: runs, dtype: int64

# %%
vk[-5:]  # but it can work while slicing
# Out:
# match_no
# 263     70
# 264     95
# 265    114
# 266    117
# 267      8
# Name: runs, dtype: int64

# %%
m[-5:]
# Out:
#                   Movie      Lead Actor
# 245   Aashiqui Ka Safar    Tiger Shroff
# 246        Ishq Forever     Salman Khan
# 247  Bandhan Ek Dastaan  Shah Rukh Khan
# 248          Prem Story      Ajay Devgn
# 249  Aashiqui Ki Kahani   Shahid Kapoor

# %%
# fancy indexing
vk[[1,3,4,5]]
# Out:
# match_no
# 1    43
# 3    40
# 4    45
# 5     7
# Name: runs, dtype: int64

# %%
# indexing with labels
m[m['Lead Actor'] == 'Tiger Shroff']
# Out:
#                    Movie    Lead Actor
# 4           Dil Reloaded  Tiger Shroff
# 14       Zindagi Returns  Tiger Shroff
# 22        Dosti Reloaded  Tiger Shroff
# 42           Dosti Story  Tiger Shroff
# 43          Raaz Forever  Tiger Shroff
# 63        Dosti Ka Safar  Tiger Shroff
# 67        Aashiqui Story  Tiger Shroff
# 76   Zindagi The Journey  Tiger Shroff
# 83        Dosti Ka Safar  Tiger Shroff
# 90          Prem Forever  Tiger Shroff
# 119   Aashiqui Ki Kahani  Tiger Shroff
# 157          Prem Reborn  Tiger Shroff
# 160      Ishq Ek Dastaan  Tiger Shroff
# 195       Dosti Reloaded  Tiger Shroff
# 236      Bandhan Returns  Tiger Shroff
# 245    Aashiqui Ka Safar  Tiger Shroff

# %% [markdown]
# # Editing Series

# %%
#using_indexing
a
# Out:
# maths      23
# english    23
# hindi      12
# science    43
# dtype: int64

# %%
a[1] = 99
a
# Out:
# C:\Users\divya\AppData\Local\Temp\ipykernel_20920\1617183807.py:1: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   a[1] = 99
# maths      23
# english    99
# hindi      12
# science    43
# dtype: int64

# %%
# what if an index does not exist
a['sst'] = 91     #  it will create
a
# Out:
# maths        1
# english    100
# hindi       99
# science     99
# sst         91
# dtype: int64

# %%
#slicing
a[2:4] = [99,99]
a
# Out:
# maths        1
# english    100
# hindi       99
# science     99
# sst         91
# dtype: int64

# %%
#fancy indexing
a[["maths","sst"]] = [1,2]
a
# Out:
# maths        1
# english    100
# hindi       99
# science     99
# sst          2
# dtype: int64

# %%
# using index label
m.loc[m['Lead Actor'] == 'Tiger Shroff', 'Movie'] = 'Avengers' # IT WILL CHANGE ALL MOVIES OF TIGER SHROFF TO AVENGERS

# %%
'''
Important Pandas Rule
Code	What happens
df['NewColumn'] = value	:creates new column
df.loc[condition, column] = value	:edits existing rows
'''
# Out:
# "\nImportant Pandas Rule\nCode\tWhat happens\ndf['NewColumn'] = value\tcreates new column\ndf.loc[condition, column] = value\tedits existing rows\n"

# %%
m
# Out:
#                   Movie      Lead Actor
# 0         Prem Ka Safar     Salman Khan
# 1     Zindagi Ki Kahani   Kartik Aaryan
# 2       Raaz Ek Dastaan   Shahid Kapoor
# 3       Dosti Ki Kahani   Kartik Aaryan
# 4              Avengers    Tiger Shroff
# ..                  ...             ...
# 245            Avengers    Tiger Shroff
# 246        Ishq Forever     Salman Khan
# 247  Bandhan Ek Dastaan  Shah Rukh Khan
# 248          Prem Story      Ajay Devgn
# 249  Aashiqui Ki Kahani   Shahid Kapoor
#
# [250 rows x 2 columns]

# %% [markdown]
# # Series with Python Functionalities

# %%
print(len(vk))
print(type(vk))
# print(dir(vk))  # shows all attributes and methods used in vk
print(sorted(vk))
print(min(vk))
print(max(vk))
# Out:
# 267
# <class 'pandas.core.series.Series'>
# ...

# %%
#type conversion
a,list(a),dict(a)
# Out:
# (maths        1
#  english    100
#  hindi       99
#  science     99
#  sst          2
#  dtype: int64,
#  [1, 100, 99, 99, 2],
#  {'maths': np.int64(1),
#   'english': np.int64(100),
#   'hindi': np.int64(99),
#   'science': np.int64(99),
#   'sst': np.int64(2)})

# %%
# membership operator
99 in vk,120 in vk.values  # first one will search on index (vk.index) and second one in values
# Out:
# (True, True)

# %%
#Looping
for i in a:
    print(i)
# Out:
# 1
# 100
# 99
# 99
# 2

# %%
#Arithmetic Operators(Broadcasting)
100 - a,a  #can use +,*,**,/
# Out:
# (maths      99
#  english     0
#  hindi       1
#  science     1
#  sst        98
#  dtype: int64,
#  maths        1
#  english    100
#  hindi       99
#  science     99
#  sst          2
#  dtype: int64)

# %%
# Relational operators
vk>=50
# Out:
# match_no
# 1      False
# 2       True
# 3      False
# 4      False
# 5      False
#        ...
# 263     True
# 264     True
# 265     True
# 266     True
# 267    False
# Name: runs, Length: 267, dtype: bool

# %%
vk[vk>=50]
# Out:
# match_no
# 2      116
# 6       75
# 7      100
# 8      105
# 9       72
#       ...
# 262     59
# 263     70
# 264     95
# 265    114
# 266    117
# Name: runs, Length: 161, dtype: int64

# %%
#Boolean indexing on series
# q. find no of 50's and 100's scored by kohli and ducks
vk[vk>=50].size,vk[vk == 100].size
# Out:
# (161, 1)

# %%
# q. find name of actors with movies more than 3
mov = m.value_counts()
mov[mov>3]
# Out:
# Movie     Lead Actor
# Avengers  Tiger Shroff    16
# Name: count, dtype: int64

# %%
# Plotting graphs on Series
vk.plot()
# Out:
# <Axes: xlabel='match_no'>

# %%
m.value_counts().head(20).plot(kind = 'pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Some imp series methods

# %%
# astype  it will change the datatype
import sys
sys.getsizeof(vk)
sys.getsizeof(vk.astype("int16"))
# Out:
# 10998

# %%
# between
vk[vk.between(51,99)].size  # both are included
# Out:
# 109

# %%
# clip
vk.clip(100,200)      # 100 se kam 100 200 se jyada 200 and beech ki same
# Out:
# match_no
# 1      100
# 2      116
# 3      100
# 4      100
# 5      100
#       ...
# 263    100
# 264    100
# 265    114
# 266    117
# 267    100
# Name: runs, Length: 267, dtype: int64

# %%
#drop_duplicates
temp = pd.Series([1,2,3,3,1,np.nan,2,3,5,4,3,2,np.nan,2,3,10,12,82,np.nan])
temp.drop_duplicates()
# Out:
# 0      1.0
# 1      2.0
# 2      3.0
# 5      NaN
# 8      5.0
# 9      4.0
# 15    10.0
# 16    12.0
# 17    82.0
# dtype: float64

# %%
temp.drop_duplicates(keep = 'last') # by default keep is first  it
# Out:
# 4      1.0
# 8      5.0
# 9      4.0
# 13     2.0
# 14     3.0
# 15    10.0
# 16    12.0
# 17    82.0
# 18     NaN
# dtype: float64

# %%
vk.duplicated().sum()  # it will give the total duplicate values
# Out:
# np.int64(158)

# %%
#isnull  give the total no. of null values

# %%
temp.isnull().sum()
# Out:
# np.int64(3)

# %%
#dropna
temp.dropna()  # it will drop the null values
# Out:
# 0      1.0
# 1      2.0
# 2      3.0
# 3      3.0
# 4      1.0
# 6      2.0
# 7      3.0
# 8      5.0
# 9      4.0
# 10     3.0
# 11     2.0
# 13     2.0
# 14     3.0
# 15    10.0
# 16    12.0
# 17    82.0
# dtype: float64

# %%
# fillna (it will change null values to any given value)
temp.fillna("boom")
# Out:
# 0      1.0
# 1      2.0
# 2      3.0
# 3      3.0
# 4      1.0
# 5     boom
# 6      2.0
# 7      3.0
# 8      5.0
# 9      4.0
# 10     3.0
# 11     2.0
# 12    boom
# 13     2.0
# 14     3.0
# 15    10.0
# 16    12.0
# 17    82.0
# 18    boom
# dtype: object

# %%
# isin
vk[vk.isin([99,49])]  # it will find is 99 and 49 is in the table
# Out:
# match_no
# 106    49
# 147    99
# 256    99
# Name: runs, dtype: int64

# %%
# apply (make your own function)
m['Lead Actor'].apply(lambda x: x.split()[0].upper())
# Out:
# 0      SALMAN
# 1      KARTIK
# 2      SHAHID
# 3      KARTIK
# 4       TIGER
#         ...
# 245     TIGER
# 246    SALMAN
# 247      SHAH
# 248      AJAY
# 249    SHAHID
# Name: Lead Actor, Length: 250, dtype: object

# %%
vk.apply(lambda x:"king" if x>100 else "chokli")
# Out:
# match_no
# 1      chokli
# 2        king
# 3      chokli
# 4      chokli
# 5      chokli
#         ...
# 263    chokli
# 264    chokli
# 265      king
# 266      king
# 267    chokli
# Name: runs, Length: 267, dtype: object

# %%
#copy  note:head and tail changes the real data to avoid use copy

# %%
vk
# Out:
# match_no
# 1       43
# 2      116
# 3       40
# 4       45
# 5        7
#       ...
# 263     70
# 264     95
# 265    114
# 266    117
# 267      8
# Name: runs, Length: 267, dtype: int64

# %%
new = vk.head().copy()
new
# Out:
# match_no
# 1     43
# 2    116
# 3     40
# 4     45
# 5      7
# Name: runs, dtype: int64

# %%
new[1] = 100
new
# Out:
# match_no
# 1    100
# 2    116
# 3     40
# 4     45
# 5      7
# Name: runs, dtype: int64

# %%
vk  # not changed because used copy function
# Out:
# match_no
# 1       43
# 2      116
# 3       40
# 4       45
# 5        7
#       ...
# 263     70
# 264     95
# 265    114
# 266    117
# 267      8
# Name: runs, Length: 267, dtype: int64
