# %% [markdown]
# # 🎌 Top Anime EDA — Production-Grade Data Analysis
#
# ---
#
# ## 📖 About This Notebook
#
# Welcome! This notebook walks you through **every key step** a data analyst performs when working with a new dataset — from raw data all the way to actionable insights. If you're learning data analysis, follow the **'Why We Do This'** sections in each step to understand *purpose* behind every action.
#
# ### Dataset Overview
# - **Source:** Top 1000 Anime from MyAnimeList (MAL)
# - **Rows:** 1,000 anime titles
# - **Columns:** 22 features including scores, genres, studios, episodes, air dates, ratings, and more
#
# ### What We'll Cover
# 1. **Environment Setup** — import libraries, configure defaults
# 2. **Data Loading & Initial Inspection** — understand the shape and structure
# 3. **Data Cleaning** — handle missing values, fix dtypes, clean dirty strings
# 4. **Univariate Analysis** — explore one variable at a time
# 5. **Bivariate / Multivariate Analysis** — find relationships between variables
# 6. **Feature Engineering** — create new, more useful columns from raw data
# 7. **Correlation Analysis** — measure linear relationships numerically
# 8. **Outlier Detection** — find anomalies using IQR and Z-Score
# 9. **Key Insights & Business Questions** — answer real questions with data
# 10. **Summary & Recommendations** — wrap up findings for a stakeholder
#
# ---
# > **Pro Tip:** In production, every notebook is a *story*. Your job as a data analyst is to guide the reader from raw data → understanding → decisions.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as mlt

# %% [markdown]
# ## 2. 📥 Data Loading & Initial Inspection
#
# ### Why We Do This
# The **first look** at your data is critical. Before writing a single line of analysis code, you need to answer:
# - How large is the dataset? (rows × columns)
# - What are the column names and data types?
# - Are there obvious missing values?
# - Do the values *make sense* at a glance?
#
# Skipping this step leads to subtle bugs — like treating a numeric column stored as `str` as a number, or ignoring 40% missing data.

# %%
df = pd.read_csv(r"C:\Users\divya\Downloads\Top_Anime_data.csv")

# %%
df.sample(10)
# Out:
#      Score  Popularity  Rank  Members  \
# 901   7.84        4274   902       26
# 20    8.90        1006    21      240
# 272   8.29         754   273      317
# 141   8.47         203   142      863
# 459   8.13         972   460      250
# 86    8.60         354    87      609
# 3     9.06         342     4      630
# 251   8.31        1747   252      127
# 435   8.15        4487   436       24
# 563   8.05         616   564      379
#
#                                            Description  \
# 901  In this world, angels, demons, and other super...
# 20   When Gintoki apprehends a movie pirate at a pr...
# 272  Kino, a 15-year-old traveler, forms a bond wit...
# 141  Aslan Jade Callenreese, known as Ash Lynx, was...
# 459  In the year 5053, French aristocrats Viscount ...
# 86   On a cold December day, Kyon arrives at school...
# 3    Gintoki, Shinpachi, and Kagura return as the f...
# 251  A year after the devastating battle against th...
# 435  Several months have passed since the Jewel See...
# 563  As Mikado Ryuugamine continues to purge the Do...
#
#                                               Synonyms  \
# 901                1031 Wan Sheng Jie, Bansei Gai, 万圣街
# 20   Gintama: The Final Chapter - Be Forever Yorozu...
# 272                Kino's Travels: The Beautiful World
# 141                                                NaN
# 459                             The King of the Cavern
# 86   The Vanishment of Haruhi Suzumiya, Suzumiya Ha...
# 3                                      Gintama' (2015)
# 251           Kingdom Hisho Hen, Kingdom: Dai 2 Series
# 435                                                NaN
# 563                                 Durarara!!x2 Ketsu
#
#                           Japanese  \
# 901                            万聖街
# 20             劇場版 銀魂 完結篇 万事屋よ永遠なれ
# 272     キノの旅 -the Beautiful World-
# 141                    BANANA FISH
# 459                            巌窟王
# 86                        涼宮ハルヒの消失
# 3                              銀魂°
# 251                   キングダム 第2シリーズ
# 435  魔法少女リリカルなのは The MOVIE 2nd A's
# 563                    デュラララ!!×2 結
#
#                                                English   Type Episodes  ...  \
# 901                                  All Saints Street    ONA       12  ...
# 20   Gintama: The Movie: The Final Chapter: Be Fore...  Movie        1  ...
# 272                                     Kino's Journey     TV       13  ...
# 141                                        Banana Fish     TV       24  ...
# 459              Gankutsuou: The Count of Monte Cristo     TV       24  ...
# 86                The Disappearance of Haruhi Suzumiya  Movie        1  ...
# 3                                     Gintama Season 4     TV       51  ...
# 251                                  Kingdom: Season 2     TV       39  ...
# 435     Magical Girl Lyrical Nanoha: The Movie 2nd A's  Movie        1  ...
# 563                                Durarara!! x2 Ketsu     TV       12  ...
#
#        Premiered                  Broadcast  \
# 901          NaN                        NaN
# 20           NaN                        NaN
# 272  Spring 2003    Tuesdays at 18:30 (JST)
# 141  Summer 2018     Fridays at 00:55 (JST)
# 459    Fall 2004    Tuesdays at 02:12 (JST)
# 86           NaN                        NaN
# 3    Spring 2015  Wednesdays at 18:00 (JST)
# 251  Summer 2013     Sundays at 23:45 (JST)
# 435          NaN                        NaN
# 563  Winter 2016   Saturdays at 23:30 (JST)
#
#                                              Producers  \
# 901  Tencent Penguin Pictures, Tianwen Kadokawa Ani...
# 20   TV Tokyo, Aniplex, Dentsu, Bandai, Warner Bros...
# 272  WOWOW, Genco, Pony Canyon, Studio Wombat, char...
# 141        Aniplex, Dentsu, Movic, Fuji TV, Shogakukan
# 459  GDH, TV Asahi, Media Factory, Sotsu Music Publ...
# 86                       Kadokawa Shoten, Animation Do
# 3                            TV Tokyo, Aniplex, Dentsu
# 251                               NHK, NHK Enterprises
# 435                                 Good Smile Company
# 563                                            Aniplex
#
#                                 Licensors                Studios       Source  \
# 901                    Aniplex of America             Fenz, HMCH    Web manga
# 20                   None found, add some                Sunrise        Manga
# 272           ADV Films, Sentai Filmworks               A.C.G.T.  Light novel
# 141                  None found, add some                  MAPPA        Manga
# 459  Funimation, Geneon Entertainment USA                  Gonzo        Novel
# 86       Funimation, Bandai Entertainment        Kyoto Animation  Light novel
# 3                 Funimation, Crunchyroll  Bandai Namco Pictures        Manga
# 251                            Funimation                Pierrot        Manga
# 435                  None found, add some             Seven Arcs     Original
# 563                    Aniplex of America                  Shuka  Light novel
#
#                                                 Genres     Demographic  \
# 901                       ComedyComedy, FantasyFantasy             NaN
# 20            ActionAction, ComedyComedy, Sci-FiSci-Fi  ShounenShounen
# 272     AdventureAdventure, DramaDrama, FantasyFantasy             NaN
# 141  ActionAction, AdventureAdventure, DramaDrama, ...    ShoujoShoujo
# 459  Award WinningAward Winning, DramaDrama, Myster...             NaN
# 86   Award WinningAward Winning, MysteryMystery, Sc...             NaN
# 3             ActionAction, ComedyComedy, Sci-FiSci-Fi  ShounenShounen
# 251                                                NaN    SeinenSeinen
# 435  ActionAction, ComedyComedy, DramaDrama, Sci-Fi...             NaN
# 563  ActionAction, MysteryMystery, SupernaturalSupe...             NaN
#
#             Duration                          Rating
# 901   4 min. per ep.       PG-13 - Teens 13 or older
# 20     1 hr. 50 min.       PG-13 - Teens 13 or older
# 272  24 min. per ep.  R - 17+ (violence & profanity)
# 141  22 min. per ep.  R - 17+ (violence & profanity)
# 459  24 min. per ep.  R - 17+ (violence & profanity)
# 86     2 hr. 41 min.       PG-13 - Teens 13 or older
# 3    24 min. per ep.       PG-13 - Teens 13 or older
# 251  25 min. per ep.  R - 17+ (violence & profanity)
# 435    2 hr. 29 min.                R+ - Mild Nudity
# 563  24 min. per ep.  R - 17+ (violence & profanity)
#
# [10 rows x 22 columns]

# %%
df.tail()
# Out:
#      Score  Popularity  Rank  Members  \
# 995    7.8        4003   996       31
# 996    7.8        1658   997      136
# 997    7.8        3114   998       50
# 998    7.8        3194   999       47
# 999    7.8        3598  1000       38
#
#                                            Description  \
# 995  Half retelling of the original Frontier series...
# 996  Not so long ago, mysterious structures called ...
# 997  Fifteen years ago in a barren stretch of the P...
# 998  Serial murders involving all kinds have happen...
# 999  One foggy morning, a black and white Toyota AE...
#
#                                               Synonyms  \
# 995  Macross Frontier the Movie, Gekijouban Macross...
# 996                      Magi: Adventure of Sinbad OVA
# 997                                                NaN
# 998   Meitantei Conan: Senritsu no Gakufu [Full Score]
# 999      Shin Gekijouban Initial D: Legend 1 - Kakusei
#
#                           Japanese  \
# 995     劇場版 マクロスＦ 虚空歌姫 ～イツワリノウタヒメ～
# 996                   マギ シンドバッドの冒険
# 997                 名探偵コナン 水平線上の陰謀
# 998            名探偵コナン 戦慄の楽譜（フルスコア）
# 999  新劇場版 頭文字［イニシャル］D Legend1 -覚醒-
#
#                                                English   Type Episodes  ...  \
# 995             Macross Frontier: The False Songstress  Movie        1  ...
# 996                                                NaN    OVA        5  ...
# 997  Detective Conan Movie 09: Strategy Above the D...  Movie        1  ...
# 998       Detective Conan Movie 12: Full Score of Fear  Movie        1  ...
# 999                       Initial D Legend 1 Awakening  Movie        1  ...
#
#     Premiered Broadcast                                          Producers  \
# 995       NaN       NaN  Bandai Visual, Big West, KlockWorx, Bandai Nam...
# 996       NaN       NaN                                Aniplex, Shogakukan
# 997       NaN       NaN                               None found, add some
# 998       NaN       NaN  Shogakukan-Shueisha Productions, Tokyo Movie S...
# 999       NaN       NaN  Shochiku, Kodansha, Ultra Super Pictures, Avex...
#
#                 Licensors               Studios    Source  \
# 995  None found, add some       Satelight, 8bit  Original
# 996  None found, add some              Lay-duce     Manga
# 997  None found, add some     TMS Entertainment     Manga
# 998  None found, add some     TMS Entertainment     Manga
# 999      Sentai Filmworks  SANZIGEN, LIDENFILMS     Manga
#
#                                                Genres     Demographic  \
# 995        ActionAction, RomanceRomance, Sci-FiSci-Fi             NaN
# 996  ActionAction, AdventureAdventure, FantasyFantasy  ShounenShounen
# 997  AdventureAdventure, ComedyComedy, MysteryMystery  ShounenShounen
# 998  AdventureAdventure, ComedyComedy, MysteryMystery  ShounenShounen
# 999                                               NaN    SeinenSeinen
#
#             Duration                     Rating
# 995    1 hr. 59 min.  PG-13 - Teens 13 or older
# 996  24 min. per ep.  PG-13 - Teens 13 or older
# 997    1 hr. 50 min.  PG-13 - Teens 13 or older
# 998    1 hr. 56 min.  PG-13 - Teens 13 or older
# 999     1 hr. 2 min.  PG-13 - Teens 13 or older
#
# [5 rows x 22 columns]

# %%
df.shape,df.describe()
# Out:
# ((1000, 22),
#               Score    Popularity         Rank      Members
#  count  1000.000000   1000.000000  1000.000000  1000.000000
#  mean      8.156580   1805.637000   500.500000   223.648000
#  std       0.284344   1888.308553   288.819436   246.288299
#  min       7.800000      1.000000     1.000000     1.000000
#  25%       7.920000    413.750000   250.750000    31.750000
#  50%       8.100000   1139.500000   500.500000   132.000000
#  75%       8.312500   2633.750000   750.250000   330.000000
#  max       9.380000  12043.000000  1000.000000   998.000000)

# %% [markdown]
# ## 3. 🧹 Data Cleaning
#
# ### Why We Do This
# Real-world data is never clean. Cleaning is **not busywork** — it directly affects the accuracy of every analysis downstream. We need to:
#
# 1. **Quantify missing data** — decide whether to drop, fill, or flag each missing column
# 2. **Fix dirty strings** — this dataset has duplicated text in some columns (e.g., `'ActionAction'`)
# 3. **Parse messy formats** — dates and durations are stored as plain text; we need them as numbers
# 4. **Standardize categorical values** — avoid counting the same thing as two different categories
#
# > **Production Rule:** Never modify the original DataFrame in place without first understanding what you're changing and why.

# %% [markdown]
# ## 3.1 Missing Value Audit
#
# Calculate both the **count** and **percentage** of missing values for each column.
#
# > ⚠️ **Why percentage matters more than count:**
# >
# > - 50 missing values out of 100 → **Critical (50%)**
# > - 50 missing values out of 1,000,000 → **Negligible (0.005%)**
#
# ### Key Idea
# Always prioritize **percentage of missing data** over raw counts when assessing data quality.

# %%
df.head()
# Out:
#    Score  Popularity  Rank  Members  \
# 0   9.38         284     1      710
# 1   9.09           3     2        3
# 2   9.07          13     3        2
# 3   9.06         342     4      630
# 4   9.05          21     5        2
#
#                                          Description  \
# 0  During their decade-long quest to defeat the D...
# 1  After a horrific alchemy experiment goes wrong...
# 2  Eccentric scientist Rintarou Okabe has a never...
# 3  Gintoki, Shinpachi, and Kagura return as the f...
# 4  Seeking to restore humanity's diminishing hope...
#
#                                             Synonyms  \
# 0                             Frieren at the Funeral
# 1  Hagane no Renkinjutsushi: Fullmetal Alchemist,...
# 2                                                NaN
# 3                                    Gintama' (2015)
# 4                                                NaN
#
#                      Japanese                           English Type Episodes  \
# 0                    葬送のフリーレン     Frieren: Beyond Journey's End   TV       28
# 1  鋼の錬金術師 FULLMETAL ALCHEMIST  Fullmetal Alchemist: Brotherhood   TV       64
# 2                 STEINS;GATE                       Steins;Gate   TV       24
# 3                         銀魂°                  Gintama Season 4   TV       51
# 4        進撃の巨人 Season3 Part.2   Attack on Titan Season 3 Part 2   TV       10
#
#    ...    Premiered                  Broadcast  \
# 0  ...    Fall 2023     Fridays at 23:00 (JST)
# 1  ...  Spring 2009     Sundays at 17:00 (JST)
# 2  ...  Spring 2011  Wednesdays at 02:05 (JST)
# 3  ...  Spring 2015  Wednesdays at 18:00 (JST)
# 4  ...  Spring 2019     Mondays at 00:10 (JST)
#
#                                            Producers  \
# 0  Aniplex, Dentsu, Shogakukan-Shueisha Productio...
# 1  Aniplex, Square Enix, Mainichi Broadcasting Sy...
# 2  Frontier Works, Media Factory, Kadokawa Shoten...
# 3                          TV Tokyo, Aniplex, Dentsu
# 4  Production I.G, Dentsu, Mainichi Broadcasting ...
#
#                         Licensors                Studios        Source  \
# 0            None found, add some               Madhouse         Manga
# 1  Funimation, Aniplex of America                  Bones         Manga
# 2                      Funimation              White Fox  Visual novel
# 3         Funimation, Crunchyroll  Bandai Namco Pictures         Manga
# 4                      Funimation             Wit Studio         Manga
#
#                                               Genres     Demographic  \
# 0     AdventureAdventure, DramaDrama, FantasyFantasy  ShounenShounen
# 1  ActionAction, AdventureAdventure, DramaDrama, ...  ShounenShounen
# 2         DramaDrama, Sci-FiSci-Fi, SuspenseSuspense             NaN
# 3           ActionAction, ComedyComedy, Sci-FiSci-Fi  ShounenShounen
# 4         ActionAction, DramaDrama, SuspenseSuspense  ShounenShounen
#
#           Duration                          Rating
# 0  24 min. per ep.       PG-13 - Teens 13 or older
# 1  24 min. per ep.  R - 17+ (violence & profanity)
# 2  24 min. per ep.       PG-13 - Teens 13 or older
# 3  24 min. per ep.       PG-13 - Teens 13 or older
# 4  23 min. per ep.  R - 17+ (violence & profanity)
#
# [5 rows x 22 columns]

# %%
df.isnull().sum()
# Out:
# Score            0
# Popularity       0
# Rank             0
# Members          0
# Description      0
# Synonyms       291
# Japanese         1
# English        141
# Type             0
# Episodes         0
# Status           0
# Aired            0
# Premiered      431
# Broadcast      431
# Producers        0
# Licensors        0
# Studios          0
# Source           0
# Genres         229
# Demographic    479
# Duration         0
# Rating           0
# dtype: int64

# %%
missing = pd.DataFrame({
'count': df.isnull().sum(),
    'percentage': (df.isnull().sum()/len(df))*100
    
})
missing
# Out:
#              count  percentage
# Score            0         0.0
# Popularity       0         0.0
# Rank             0         0.0
# Members          0         0.0
# Description      0         0.0
# Synonyms       291        29.1
# Japanese         1         0.1
# English        141        14.1
# Type             0         0.0
# Episodes         0         0.0
# Status           0         0.0
# Aired            0         0.0
# Premiered      431        43.1
# Broadcast      431        43.1
# Producers        0         0.0
# Licensors        0         0.0
# Studios          0         0.0
# Source           0         0.0
# Genres         229        22.9
# Demographic    479        47.9
# Duration         0         0.0
# Rating           0         0.0

# %%
missing[missing['count'] != 0]
# Out:
#              count  percentage
# Synonyms       291        29.1
# Japanese         1         0.1
# English        141        14.1
# Premiered      431        43.1
# Broadcast      431        43.1
# Genres         229        22.9
# Demographic    479        47.9

# %% [markdown]
# ## 3.2 Fill / Handle Missing Values
#
# Before handling missing data, create a **working copy** of the dataset.
#
# > ⚠️ **Important Practice:**
# >
# > Never modify the original dataset (`df`) directly.
#
# ### Why?
#
# - Preserves the **raw data** for reference
# - Prevents accidental data loss or corruption
# - Makes your workflow **reproducible and safe**
#
# ### Best Practice
#
# In production environments:
#
# - Keep the original dataset as: `df` *(raw data)*
# - Perform all cleaning and transformations on: `df_clean`

# %%
df_clean = df.copy()

# %%
df_clean.head()
# Out:
#    Score  Popularity  Rank  Members  \
# 0   9.38         284     1      710
# 1   9.09           3     2        3
# 2   9.07          13     3        2
# 3   9.06         342     4      630
# 4   9.05          21     5        2
#
#                                          Description  \
# 0  During their decade-long quest to defeat the D...
# 1  After a horrific alchemy experiment goes wrong...
# 2  Eccentric scientist Rintarou Okabe has a never...
# 3  Gintoki, Shinpachi, and Kagura return as the f...
# 4  Seeking to restore humanity's diminishing hope...
#
#                                             Synonyms  \
# 0                             Frieren at the Funeral
# 1  Hagane no Renkinjutsushi: Fullmetal Alchemist,...
# 2                                                NaN
# 3                                    Gintama' (2015)
# 4                                                NaN
#
#                      Japanese                           English Type Episodes  \
# 0                    葬送のフリーレン     Frieren: Beyond Journey's End   TV       28
# 1  鋼の錬金術師 FULLMETAL ALCHEMIST  Fullmetal Alchemist: Brotherhood   TV       64
# 2                 STEINS;GATE                       Steins;Gate   TV       24
# 3                         銀魂°                  Gintama Season 4   TV       51
# 4        進撃の巨人 Season3 Part.2   Attack on Titan Season 3 Part 2   TV       10
#
#    ...    Premiered                  Broadcast  \
# 0  ...    Fall 2023     Fridays at 23:00 (JST)
# 1  ...  Spring 2009     Sundays at 17:00 (JST)
# 2  ...  Spring 2011  Wednesdays at 02:05 (JST)
# 3  ...  Spring 2015  Wednesdays at 18:00 (JST)
# 4  ...  Spring 2019     Mondays at 00:10 (JST)
#
#                                            Producers  \
# 0  Aniplex, Dentsu, Shogakukan-Shueisha Productio...
# 1  Aniplex, Square Enix, Mainichi Broadcasting Sy...
# 2  Frontier Works, Media Factory, Kadokawa Shoten...
# 3                          TV Tokyo, Aniplex, Dentsu
# 4  Production I.G, Dentsu, Mainichi Broadcasting ...
#
#                         Licensors                Studios        Source  \
# 0            None found, add some               Madhouse         Manga
# 1  Funimation, Aniplex of America                  Bones         Manga
# 2                      Funimation              White Fox  Visual novel
# 3         Funimation, Crunchyroll  Bandai Namco Pictures         Manga
# 4                      Funimation             Wit Studio         Manga
#
#                                               Genres     Demographic  \
# 0     AdventureAdventure, DramaDrama, FantasyFantasy  ShounenShounen
# 1  ActionAction, AdventureAdventure, DramaDrama, ...  ShounenShounen
# 2         DramaDrama, Sci-FiSci-Fi, SuspenseSuspense             NaN
# 3           ActionAction, ComedyComedy, Sci-FiSci-Fi  ShounenShounen
# 4         ActionAction, DramaDrama, SuspenseSuspense  ShounenShounen
#
#           Duration                          Rating
# 0  24 min. per ep.       PG-13 - Teens 13 or older
# 1  24 min. per ep.  R - 17+ (violence & profanity)
# 2  24 min. per ep.       PG-13 - Teens 13 or older
# 3  24 min. per ep.       PG-13 - Teens 13 or older
# 4  23 min. per ep.  R - 17+ (violence & profanity)
#
# [5 rows x 22 columns]

# %%
# fill the text columns with sensible default
df_clean['Synonyms'] = df_clean['Synonyms'].fillna('Unknown')
df_clean['Demographic'] = df_clean['Demographic'].fillna('Unknown')
df_clean['Genres'] = df_clean['Genres'].fillna('Unknown')
df_clean['Premiered'] = df_clean['Premiered'].fillna('Unknown')
df_clean['Broadcast'] = df_clean['Broadcast'].fillna('Unknown')
df_clean['English']  = df_clean['English'].fillna(df_clean['Japanese'])
df_clean['Japanese']  = df_clean['English'].fillna(df_clean['English'])

# %%
df_clean.isnull().sum()
# Out:
# Score          0
# Popularity     0
# Rank           0
# Members        0
# Description    0
# Synonyms       0
# Japanese       1
# English        1
# Type           0
# Episodes       0
# Status         0
# Aired          0
# Premiered      0
# Broadcast      0
# Producers      0
# Licensors      0
# Studios        0
# Source         0
# Genres         0
# Demographic    0
# Duration       0
# Rating         0
# dtype: int64

# %% [markdown]
# ## 3.3 Fix Duplicated Text in String Columns
#
# The dataset contains duplicated text patterns caused by scraping errors, such as:
#
# - `ActionAction`
# - `ShounenShounen`
#
# ### Objective
#
# Clean these values by removing repeated text while preserving the original meaning.
#
# ### Approach
#
# Use a **reusable cleaning function** with **regular expressions (regex)** to:
#
# - Detect repeated patterns in strings
# - Replace them with a single, correct value
#
# ### Why This Matters
#
# - Improves **data consistency**
# - Prevents errors in **analysis and modeling**
# - Ensures cleaner **categorical features**

# %%
import re
text = 'ActionAction'
match = re.sub(r'\b(\w+)\1\b',r'\1',text)   #re.sub(pattern, replacement, string)
match
# Out:
# 'Action'

# %%
def fix_doubled(col):
    if not isinstance(col,str):
        return col
    return re.sub(r'\b(\w+)\1\b',r'\1',col) 
for i in ['Genres','Demographic']:
    df_clean[i] = df_clean[i].apply(fix_doubled)

# %%
df_clean.sample(10)
# Out:
#      Score  Popularity  Rank  Members  \
# 368   8.21         214   369      831
# 628   8.01         817   629      297
# 337   8.22        1201   338      200
# 285   8.28         968   286      251
# 814   7.89        2052   815      101
# 923   7.83         183   924      918
# 336   8.22         557   337      411
# 682   7.97        1766   683      124
# 151   8.45         851   152      286
# 326   8.24        1172   327      205
#
#                                            Description  \
# 368  Tooru Honda has always been fascinated by the ...
# 628  Middle school student Mirai Onozawa is dissati...
# 337  Madoka Kaname and her best friend Sayaka Miki ...
# 285  Great Britain is ablaze with news of a so-call...
# 814  The Holy Britannian Empire is a powerful natio...
# 923  If a survey were conducted to see if people be...
# 336  Nanami Momozono and her familiars Tomoe and Mi...
# 682  In the Japan of the future, employing androids...
# 151  No longer concerned with military affairs, Yuk...
# 326  In Hokkaido, it is rumored that there is a sta...
#
#                                               Synonyms  \
# 368                     Furuba, Fruits Basket (Zenpen)
# 628                                            Unknown
# 337  Mahou Shoujo Madoka Magika Movie 1, Magical Gi...
# 285  Moriarty's Patriotism Part 2, Moriarty the Pat...
# 814   Code Geass: Lelouch of the Rebellion - Awakening
# 923                         Suzumiya Haruhi no Yuuutsu
# 336  Kamisama Hajimemashita 2nd Season, Kami-sama H...
# 682  Eve's Time, Eve no Jikan 1st Season Complete E...
# 151                                            Unknown
# 326                         Golden Kamuy Second Season
#
#                                               Japanese  \
# 368                           Fruits Basket 1st Season
# 628                                Tokyo Magnitude 8.0
# 337  Puella Magi Madoka Magica the Movie Part 1: Be...
# 285                        Moriarty the Patriot Part 2
# 814  Code Geass: Lelouch of the Rebellion I - Initi...
# 923                  The Melancholy of Haruhi Suzumiya
# 336                             Kamisama Kiss Season 2
# 682                                        Time of Eve
# 151                                 Bungo Stray Dogs 4
# 326                              Golden Kamuy Season 2
#
#                                                English   Type Episodes  ...  \
# 368                           Fruits Basket 1st Season     TV       25  ...
# 628                                Tokyo Magnitude 8.0     TV       11  ...
# 337  Puella Magi Madoka Magica the Movie Part 1: Be...  Movie        1  ...
# 285                        Moriarty the Patriot Part 2     TV       13  ...
# 814  Code Geass: Lelouch of the Rebellion I - Initi...  Movie        1  ...
# 923                  The Melancholy of Haruhi Suzumiya     TV       14  ...
# 336                             Kamisama Kiss Season 2     TV       12  ...
# 682                                        Time of Eve  Movie        1  ...
# 151                                 Bungo Stray Dogs 4     TV       13  ...
# 326                              Golden Kamuy Season 2     TV       12  ...
#
#        Premiered                  Broadcast  \
# 368  Spring 2019   Saturdays at 01:23 (JST)
# 628  Summer 2009     Fridays at 00:45 (JST)
# 337      Unknown                    Unknown
# 285  Spring 2021     Sundays at 22:30 (JST)
# 814      Unknown                    Unknown
# 923  Spring 2006     Mondays at 00:00 (JST)
# 336  Winter 2015    Tuesdays at 02:05 (JST)
# 682      Unknown                    Unknown
# 151  Winter 2023  Wednesdays at 23:00 (JST)
# 326    Fall 2018     Mondays at 23:00 (JST)
#
#                                              Producers  \
# 368  TV Tokyo, TV Osaka, Nihon Ad Systems, Hakusens...
# 628  Dentsu, Fuji TV, Asmik Ace, Sony Music Enterta...
# 337  Aniplex, Mainichi Broadcasting System, Movic, ...
# 285  Mainichi Broadcasting System, Shueisha, Yomiur...
# 814                               None found, add some
# 923  Lantis, Kadokawa Shoten, Kadokawa Pictures Jap...
# 336                                      Dentsu, Sotsu
# 682                                   Directions, Code
# 151  WOWOW, Lantis, Movic, Glovision, Crunchyroll, ...
# 326  Magic Capsule, NBCUniversal Entertainment Japa...
#
#                                              Licensors               Studios  \
# 368                                         Funimation     TMS Entertainment
# 628                                       Maiden Japan  Bones, Kinema Citrus
# 337                                 Aniplex of America                 Shaft
# 285                                         Funimation        Production I.G
# 814                                         Funimation               Sunrise
# 923  Funimation, Bandai Entertainment, Kadokawa Pic...       Kyoto Animation
# 336                                         Funimation     TMS Entertainment
# 682                              NYAV Post, Pied Piper          Studio Rikka
# 151                               None found, add some                 Bones
# 326                                         Funimation           Geno Studio
#
#           Source                                             Genres  \
# 368        Manga                       Drama, Romance, Supernatural
# 628     Original                  Award WinningAward Winning, Drama
# 337     Original                           Drama, Fantasy, Suspense
# 285        Manga                                  Mystery, Suspense
# 814     Original                               Action, Sci-FiSci-Fi
# 923  Light novel  Award WinningAward Winning, Comedy, Mystery, S...
# 336        Manga                           Comedy, Fantasy, Romance
# 682     Original           Sci-FiSci-Fi, Slice of LifeSlice of Life
# 151        Manga                      Action, Mystery, Supernatural
# 326        Manga                                  Action, Adventure
#
#     Demographic         Duration                          Rating
# 368      Shoujo  23 min. per ep.       PG-13 - Teens 13 or older
# 628     Unknown  22 min. per ep.       PG-13 - Teens 13 or older
# 337     Unknown    2 hr. 11 min.       PG-13 - Teens 13 or older
# 285     Shounen  23 min. per ep.  R - 17+ (violence & profanity)
# 814     Unknown    2 hr. 15 min.                R+ - Mild Nudity
# 923     Unknown  23 min. per ep.       PG-13 - Teens 13 or older
# 336      Shoujo  23 min. per ep.       PG-13 - Teens 13 or older
# 682     Unknown    1 hr. 46 min.       PG-13 - Teens 13 or older
# 151      Seinen  23 min. per ep.  R - 17+ (violence & profanity)
# 326      Seinen  23 min. per ep.  R - 17+ (violence & profanity)
#
# [10 rows x 22 columns]

# %%
df_clean.sample(10)
# Out:
#      Score  Popularity  Rank  Members  \
# 829   7.88         201   830      863
# 221   8.34        2505   222       74
# 470   8.12         694   471      338
# 105   8.55         307   106      667
# 491   8.10        2084   492       99
# 395   8.19        1748   396      126
# 866   7.86        4005   867       31
# 371   8.20        4230   372       27
# 572   8.05         793   573      303
# 772   7.91         865   773      279
#
#                                            Description  \
# 829  On a rainy morning in Tokyo, Takao Akizuki, an...
# 221  In the year 0068 of the Universal Century, Cas...
# 470  Although Jirou Horikoshi's nearsightedness pre...
# 105  Departing from their respective hometowns, two...
# 491  In the year Universal Century 0096, three year...
# 395  On a mysterious night that seems to last for a...
# 866  In the film's story, there is a sudden explosi...
# 371  The quarterfinal round of the Winter Continuou...
# 572  Whenever he is not getting pummeled in the kar...
# 772  Thirty years ago, a new race of flame-wielding...
#
#                                          Synonyms  \
# 829    Koto no Ha no Niwa, The Garden of Kotonoha
# 221                                       Unknown
# 470                                  Kaze Tachinu
# 105                                       Unknown
# 491                         Mobile Suit Gundam UC
# 395                                       Unknown
# 866  Detective Conan Movie 22: Zero's Executioner
# 371                                       Unknown
# 572          History's Strongest Disciple Kenichi
# 772                                       Unknown
#
#                                     Japanese  \
# 829                      The Garden of Words
# 221           Mobile Suit Gundam: The Origin
# 470                           The Wind Rises
# 105                                     Nana
# 491               Mobile Suit Gundam Unicorn
# 395             Night Is Short, Walk on Girl
# 866  Case Closed Movie 22: Zero the Enforcer
# 371     Girls und Panzer das Finale – Part 3
# 572          KenIchi: The Mightiest Disciple
# 772                                  Promare
#
#                                      English   Type Episodes  ...  \
# 829                      The Garden of Words  Movie        1  ...
# 221           Mobile Suit Gundam: The Origin    OVA        6  ...
# 470                           The Wind Rises  Movie        1  ...
# 105                                     Nana     TV       47  ...
# 491               Mobile Suit Gundam Unicorn    OVA        7  ...
# 395             Night Is Short, Walk on Girl  Movie        1  ...
# 866  Case Closed Movie 22: Zero the Enforcer  Movie        1  ...
# 371     Girls und Panzer das Finale – Part 3  Movie        1  ...
# 572          KenIchi: The Mightiest Disciple     TV       50  ...
# 772                                  Promare  Movie        1  ...
#
#        Premiered                  Broadcast  \
# 829      Unknown                    Unknown
# 221      Unknown                    Unknown
# 470      Unknown                    Unknown
# 105  Spring 2006  Wednesdays at 23:25 (JST)
# 491      Unknown                    Unknown
# 395      Unknown                    Unknown
# 866      Unknown                    Unknown
# 371      Unknown                    Unknown
# 572    Fall 2006     Sundays at 00:55 (JST)
# 772      Unknown                    Unknown
#
#                                              Producers  \
# 829                  The Answer Studio, TOHO animation
# 221                                              Sotsu
# 470                                            Nichion
# 105           VAP, Nippon Television Network, Shueisha
# 491                     Bandai Visual, Kadokawa Shoten
# 395                   Fuji TV, TOHO, BS Fuji, Kadokawa
# 866  Yomiuri Telecasting, TOHO, Nippon Television N...
# 371  Bandai Visual, Lantis, Movic, Q-Tec, Hakuhodo ...
# 572          TV Tokyo, Tokyo Movie Shinsha, Shogakukan
# 772                              TOHO animation, XFLAG
#
#                                              Licensors            Studios  \
# 829                                   Sentai Filmworks   CoMix Wave Films
# 221                    Nozomi Entertainment, NYAV Post            Sunrise
# 470                       Disney Platform Distribution      Studio Ghibli
# 105                        VIZ Media, Sentai Filmworks           Madhouse
# 491  Nozomi Entertainment, Bandai Entertainment, NY...            Sunrise
# 395                                              GKIDS       Science SARU
# 866                                     Discotek Media  TMS Entertainment
# 371                                   Sentai Filmworks              Actas
# 572                         Funimation, Discotek Media  TMS Entertainment
# 772                                              GKIDS            Trigger
#
#        Source                                             Genres Demographic  \
# 829  Original         Award WinningAward Winning, Drama, Romance     Unknown
# 221     Manga                               Action, Sci-FiSci-Fi     Shounen
# 470     Manga         Award WinningAward Winning, Drama, Romance     Unknown
# 105     Manga                                     Drama, Romance      Shoujo
# 491     Novel                        Action, Drama, Sci-FiSci-Fi     Unknown
# 395     Novel                                    Comedy, Romance     Unknown
# 866     Manga  Action, Award WinningAward Winning, Drama, Mys...     Unknown
# 371  Original                                            Unknown     Unknown
# 572     Manga                                     Action, Comedy     Shounen
# 772  Original                               Action, Sci-FiSci-Fi     Unknown
#
#                   Duration                     Rating
# 829                46 min.  PG-13 - Teens 13 or older
# 221  1 hr. 11 min. per ep.           R+ - Mild Nudity
# 470           2 hr. 6 min.  PG-13 - Teens 13 or older
# 105        23 min. per ep.           R+ - Mild Nudity
# 491   1 hr. 2 min. per ep.  PG-13 - Teens 13 or older
# 395          1 hr. 32 min.           R+ - Mild Nudity
# 866          1 hr. 50 min.  PG-13 - Teens 13 or older
# 371                48 min.  PG-13 - Teens 13 or older
# 572        24 min. per ep.  PG-13 - Teens 13 or older
# 772          1 hr. 51 min.  PG-13 - Teens 13 or older
#
# [10 rows x 22 columns]

# %%
df_clean.sample(7)
# Out:
#      Score  Popularity  Rank  Members  \
# 906   7.84        2750   907       63
# 576   8.04        2769   577       62
# 661   7.98        7269   662        7
# 434   8.15        3331   435       44
# 491   8.10        2084   492       99
# 230   8.33         256   231      760
# 146   8.47         579   147      395
#
#                                            Description  \
# 906  Nobita Nobi is a normal fourth grade student. ...
# 576  On a rainy afternoon, the Detective Boys witne...
# 661  To awaken his teacher Yao Cheng, Xiao Yan trav...
# 434  Genius thief Arsene Lupin III—along with the u...
# 491  In the year Universal Century 0096, three year...
# 230  The nation of Tempest is in a festive mood aft...
# 146  Japan, 1955: Mario Minakami has just arrived a...
#
#                                               Synonyms  \
# 906                                            Unknown
# 576     Detective Conan Movie 04: Captured in Her Eyes
# 661              Battle Through the Heavens 4th Season
# 434  Lupin III: Part V, Lupin Sansei Part V, Lupin ...
# 491                              Mobile Suit Gundam UC
# 230                                          Tensura 2
# 146   Rainbow: Criminal Seven of Compound Two Cell Six
#
#                                               Japanese  \
# 906                                           Doraemon
# 576         Case Closed Movie 04: Captured In Her Eyes
# 661                     Fights Break Sphere 4th Season
# 434                             Lupin the Third Part 5
# 491                         Mobile Suit Gundam Unicorn
# 230  That Time I Got Reincarnated as a Slime Season...
# 146                                            Rainbow
#
#                                                English   Type Episodes  ...  \
# 906                                           Doraemon     TV     1787  ...
# 576         Case Closed Movie 04: Captured In Her Eyes  Movie        1  ...
# 661                     Fights Break Sphere 4th Season    ONA       24  ...
# 434                             Lupin the Third Part 5     TV       24  ...
# 491                         Mobile Suit Gundam Unicorn    OVA        7  ...
# 230  That Time I Got Reincarnated as a Slime Season...     TV       12  ...
# 146                                            Rainbow     TV       26  ...
#
#        Premiered                  Broadcast  \
# 906  Spring 1979     Fridays at 19:00 (JST)
# 576      Unknown                    Unknown
# 661      Unknown                    Unknown
# 434  Spring 2018  Wednesdays at 01:29 (JST)
# 491      Unknown                    Unknown
# 230  Summer 2021    Tuesdays at 23:00 (JST)
# 146  Spring 2010  Wednesdays at 00:59 (JST)
#
#                                              Producers  \
# 906                                TV Asahi, Asatsu DK
# 576                                     Polygram Japan
# 661                           Tencent Penguin Pictures
# 434               Nippon Television Network, TMS Music
# 491                     Bandai Visual, Kadokawa Shoten
# 230  Kodansha, BS11, Bandai Namco Arts, Micro Magaz...
# 146                     VAP, Nippon Television Network
#
#                                              Licensors  \
# 906                               None found, add some
# 576                                         Funimation
# 661                               None found, add some
# 434                                     Discotek Media
# 491  Nozomi Entertainment, Bandai Entertainment, NY...
# 230                                        Crunchyroll
# 146                         Funimation, Discotek Media
#
#                     Studios Source  \
# 906       Shin-Ei Animation  Manga
# 576       TMS Entertainment  Manga
# 661            Motion Magic  Novel
# 434  Telecom Animation Film  Manga
# 491                 Sunrise  Novel
# 230                    8bit  Manga
# 146                Madhouse  Manga
#
#                                                 Genres Demographic  \
# 906           Adventure, Comedy, Fantasy, Sci-FiSci-Fi     Unknown
# 576                         Adventure, Comedy, Mystery     Shounen
# 661  Action, Adventure, Fantasy, Romance, Supernatural     Unknown
# 434                 Action, Adventure, Comedy, Mystery      Seinen
# 491                        Action, Drama, Sci-FiSci-Fi     Unknown
# 230                 Action, Adventure, Comedy, Fantasy     Shounen
# 146                                    Drama, Suspense      Seinen
#
#                  Duration                          Rating
# 906       11 min. per ep.                   PG - Children
# 576         1 hr. 40 min.       PG-13 - Teens 13 or older
# 661       24 min. per ep.       PG-13 - Teens 13 or older
# 434       22 min. per ep.       PG-13 - Teens 13 or older
# 491  1 hr. 2 min. per ep.       PG-13 - Teens 13 or older
# 230       23 min. per ep.       PG-13 - Teens 13 or older
# 146       22 min. per ep.  R - 17+ (violence & profanity)
#
# [7 rows x 22 columns]

# %% [markdown]
# ## 3.4 Parse Duration → Minutes (Numeric)
#
# The `Duration` column contains text-based values such as:
#
# - `24 min. per ep.`
# - `1 hr. 44 min.`
#
# ### Objective
#
# Convert these values into a **single numeric column (in minutes)**.
#
# ### Why This Matters
#
# - Enables **mathematical operations** (e.g., averages, comparisons)
# - Improves **model compatibility** (ML models require numeric input)
# - Standardizes inconsistent time formats
#
# ### Approach
#
# - Extract hours and minutes from the text
# - Convert everything into **total minutes**
# - Store the result in a new numeric column (e.g., `Duration_Min`)

# %%
def duration(dur):
    hours = re.search(r'\b(\d+)\s*hr\b',dur)
    minutes = re.search(r'\b(\d+)\s*min\b',dur)
    total = 0
    if hours:
        total += int(hours.group(1))*60
    if minutes:
        total += int(minutes.group(1))
    return float(total) if total>0 else np.nan    
df_clean['Duration_min'] = df_clean['Duration'].apply(duration)

# %%
df_clean['Duration_min']
# Out:
# 0       24.0
# 1       24.0
# 2       24.0
# 3       24.0
# 4       23.0
#        ...
# 995    119.0
# 996     24.0
# 997    110.0
# 998    116.0
# 999     62.0
# Name: Duration_min, Length: 1000, dtype: float64

# %% [markdown]
# ## 3.5 Parse Episodes → Integer
#
# The `Episodes` column is stored as a **string (object type)** instead of a numeric format.
#
#
# Convert this column into an **integer (numeric type)** for proper analysis.
#
# ### Approach
#
# Use `pd.to_numeric()` with `errors='coerce'`:
#
# - Converts valid numeric values to integers
# - Replaces invalid or unparseable values with `NaN` (instead of throwing errors)
#
# ### Why This Matters
#
# - Ensures **correct data types** for analysis
# - Prevents runtime errors during transformations
# - Safely handles messy or inconsistent data

# %%
df_clean['Episodes'] = pd.to_numeric(df_clean['Episodes'],errors='coerce')

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 23 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Score         1000 non-null   float64
#  1   Popularity    1000 non-null   int64
#  2   Rank          1000 non-null   int64
#  3   Members       1000 non-null   int64
#  4   Description   1000 non-null   object
#  5   Synonyms      1000 non-null   object
#  6   Japanese      999 non-null    object
#  7   English       999 non-null    object
#  8   Type          1000 non-null   object
#  9   Episodes      997 non-null    float64
#  10  Status        1000 non-null   object
#  11  Aired         1000 non-null   object
#  12  Premiered     1000 non-null   object
#  13  Broadcast     1000 non-null   object
#  14  Producers     1000 non-null   object
#  15  Licensors     1000 non-null   object
#  16  Studios       1000 non-null   object
#  17  Source        1000 non-null   object
#  18  Genres        1000 non-null   object
#  19  Demographic   1000 non-null   object
#  20  Duration      1000 non-null   object
#  21  Rating        1000 non-null   object
#  22  Duration_min  1000 non-null   float64
# dtypes: float64(3), int64(3), object(17)
# memory usage: 179.8+ KB

# %%
df_clean.head(5)
# Out:
#    Score  Popularity  Rank  Members  \
# 0   9.38         284     1      710
# 1   9.09           3     2        3
# 2   9.07          13     3        2
# 3   9.06         342     4      630
# 4   9.05          21     5        2
#
#                                          Description  \
# 0  During their decade-long quest to defeat the D...
# 1  After a horrific alchemy experiment goes wrong...
# 2  Eccentric scientist Rintarou Okabe has a never...
# 3  Gintoki, Shinpachi, and Kagura return as the f...
# 4  Seeking to restore humanity's diminishing hope...
#
#                                             Synonyms  \
# 0                             Frieren at the Funeral
# 1  Hagane no Renkinjutsushi: Fullmetal Alchemist,...
# 2                                            Unknown
# 3                                    Gintama' (2015)
# 4                                            Unknown
#
#                            Japanese                           English Type  \
# 0     Frieren: Beyond Journey's End     Frieren: Beyond Journey's End   TV
# 1  Fullmetal Alchemist: Brotherhood  Fullmetal Alchemist: Brotherhood   TV
# 2                       Steins;Gate                       Steins;Gate   TV
# 3                  Gintama Season 4                  Gintama Season 4   TV
# 4   Attack on Titan Season 3 Part 2   Attack on Titan Season 3 Part 2   TV
#
#    Episodes  ...                  Broadcast  \
# 0      28.0  ...     Fridays at 23:00 (JST)
# 1      64.0  ...     Sundays at 17:00 (JST)
# 2      24.0  ...  Wednesdays at 02:05 (JST)
# 3      51.0  ...  Wednesdays at 18:00 (JST)
# 4      10.0  ...     Mondays at 00:10 (JST)
#
#                                            Producers  \
# 0  Aniplex, Dentsu, Shogakukan-Shueisha Productio...
# 1  Aniplex, Square Enix, Mainichi Broadcasting Sy...
# 2  Frontier Works, Media Factory, Kadokawa Shoten...
# 3                          TV Tokyo, Aniplex, Dentsu
# 4  Production I.G, Dentsu, Mainichi Broadcasting ...
#
#                         Licensors                Studios        Source  \
# 0            None found, add some               Madhouse         Manga
# 1  Funimation, Aniplex of America                  Bones         Manga
# 2                      Funimation              White Fox  Visual novel
# 3         Funimation, Crunchyroll  Bandai Namco Pictures         Manga
# 4                      Funimation             Wit Studio         Manga
#
#                               Genres Demographic         Duration  \
# 0          Adventure, Drama, Fantasy     Shounen  24 min. per ep.
# 1  Action, Adventure, Drama, Fantasy     Shounen  24 min. per ep.
# 2      Drama, Sci-FiSci-Fi, Suspense     Unknown  24 min. per ep.
# 3       Action, Comedy, Sci-FiSci-Fi     Shounen  24 min. per ep.
# 4            Action, Drama, Suspense     Shounen  23 min. per ep.
#
#                            Rating Duration_min
# 0       PG-13 - Teens 13 or older         24.0
# 1  R - 17+ (violence & profanity)         24.0
# 2       PG-13 - Teens 13 or older         24.0
# 3       PG-13 - Teens 13 or older         24.0
# 4  R - 17+ (violence & profanity)         23.0
#
# [5 rows x 23 columns]

# %% [markdown]
# ## 3.6 Parse Air Start Year
#
# The `Aired` column contains date ranges or single dates, such as:
#
# - `Sep 29, 2023 to Mar 22, 2024`
# - `Jan 8, 2021`
#
# ### Objective
#
# Extract the **start year** from these values into a separate column.
#
# ### Why This Matters
#
# - Enables **trend analysis over years/decades**
# - Simplifies **time-based grouping and visualization**
# - Reduces complexity from full date strings
#
# ### Approach
#
# - Identify the **starting date** in the string
# - Extract the **year** from that date
# - Store it in a new column (e.g., `Start_Year`)

# %%
def extract_year(date):
    match = re.search(r'\b(\d{4})\b',date)
    return match.group(1)
df_clean['Start_year'] = df_clean['Aired'].apply(extract_year)

# %%
df_clean.head()
# Out:
#    Score  Popularity  Rank  Members  \
# 0   9.38         284     1      710
# 1   9.09           3     2        3
# 2   9.07          13     3        2
# 3   9.06         342     4      630
# 4   9.05          21     5        2
#
#                                          Description  \
# 0  During their decade-long quest to defeat the D...
# 1  After a horrific alchemy experiment goes wrong...
# 2  Eccentric scientist Rintarou Okabe has a never...
# 3  Gintoki, Shinpachi, and Kagura return as the f...
# 4  Seeking to restore humanity's diminishing hope...
#
#                                             Synonyms  \
# 0                             Frieren at the Funeral
# 1  Hagane no Renkinjutsushi: Fullmetal Alchemist,...
# 2                                            Unknown
# 3                                    Gintama' (2015)
# 4                                            Unknown
#
#                            Japanese                           English Type  \
# 0     Frieren: Beyond Journey's End     Frieren: Beyond Journey's End   TV
# 1  Fullmetal Alchemist: Brotherhood  Fullmetal Alchemist: Brotherhood   TV
# 2                       Steins;Gate                       Steins;Gate   TV
# 3                  Gintama Season 4                  Gintama Season 4   TV
# 4   Attack on Titan Season 3 Part 2   Attack on Titan Season 3 Part 2   TV
#
#    Episodes  ...                                          Producers  \
# 0      28.0  ...  Aniplex, Dentsu, Shogakukan-Shueisha Productio...
# 1      64.0  ...  Aniplex, Square Enix, Mainichi Broadcasting Sy...
# 2      24.0  ...  Frontier Works, Media Factory, Kadokawa Shoten...
# 3      51.0  ...                          TV Tokyo, Aniplex, Dentsu
# 4      10.0  ...  Production I.G, Dentsu, Mainichi Broadcasting ...
#
#                         Licensors                Studios        Source  \
# 0            None found, add some               Madhouse         Manga
# 1  Funimation, Aniplex of America                  Bones         Manga
# 2                      Funimation              White Fox  Visual novel
# 3         Funimation, Crunchyroll  Bandai Namco Pictures         Manga
# 4                      Funimation             Wit Studio         Manga
#
#                               Genres Demographic         Duration  \
# 0          Adventure, Drama, Fantasy     Shounen  24 min. per ep.
# 1  Action, Adventure, Drama, Fantasy     Shounen  24 min. per ep.
# 2      Drama, Sci-FiSci-Fi, Suspense     Unknown  24 min. per ep.
# 3       Action, Comedy, Sci-FiSci-Fi     Shounen  24 min. per ep.
# 4            Action, Drama, Suspense     Shounen  23 min. per ep.
#
#                            Rating Duration_min Start_year
# 0       PG-13 - Teens 13 or older         24.0       2023
# 1  R - 17+ (violence & profanity)         24.0       2009
# 2       PG-13 - Teens 13 or older         24.0       2011
# 3       PG-13 - Teens 13 or older         24.0       2015
# 4  R - 17+ (violence & profanity)         23.0       2019
#
# [5 rows x 24 columns]

# %% [markdown]
# ## 3.7 Clean Rating Column
#
# The `Rating` column contains **verbose text labels** that can be simplified.
#
# ### Objective
#
# Convert these long rating descriptions into **short, clean, and consistent labels**.
#
# ### Why This Matters
#
# - Improves **readability** of the dataset
# - Makes **visualization and grouping** easier
# - Standardizes categories for **analysis and modeling**
#
# ### Approach
#
# - Identify common rating patterns
# - Map them to **simplified labels** (e.g., shorter categories)
# - Store the cleaned values in the same or a new column

# %%
df_clean['Rating'].unique()
# Out:
# array(['PG-13 - Teens 13 or older', 'R - 17+ (violence & profanity)',
#        'R+ - Mild Nudity', 'PG - Children', 'G - All Ages'], dtype=object)

# %%
df_clean['new_rating'] = df_clean['Rating'].str.split('-').str[0].str.strip()

# %%
df_clean.head()
# Out:
#    Score  Popularity  Rank  Members  \
# 0   9.38         284     1      710
# 1   9.09           3     2        3
# 2   9.07          13     3        2
# 3   9.06         342     4      630
# 4   9.05          21     5        2
#
#                                          Description  \
# 0  During their decade-long quest to defeat the D...
# 1  After a horrific alchemy experiment goes wrong...
# 2  Eccentric scientist Rintarou Okabe has a never...
# 3  Gintoki, Shinpachi, and Kagura return as the f...
# 4  Seeking to restore humanity's diminishing hope...
#
#                                             Synonyms  \
# 0                             Frieren at the Funeral
# 1  Hagane no Renkinjutsushi: Fullmetal Alchemist,...
# 2                                            Unknown
# 3                                    Gintama' (2015)
# 4                                            Unknown
#
#                            Japanese                           English Type  \
# 0     Frieren: Beyond Journey's End     Frieren: Beyond Journey's End   TV
# 1  Fullmetal Alchemist: Brotherhood  Fullmetal Alchemist: Brotherhood   TV
# 2                       Steins;Gate                       Steins;Gate   TV
# 3                  Gintama Season 4                  Gintama Season 4   TV
# 4   Attack on Titan Season 3 Part 2   Attack on Titan Season 3 Part 2   TV
#
#    Episodes  ...                       Licensors                Studios  \
# 0      28.0  ...            None found, add some               Madhouse
# 1      64.0  ...  Funimation, Aniplex of America                  Bones
# 2      24.0  ...                      Funimation              White Fox
# 3      51.0  ...         Funimation, Crunchyroll  Bandai Namco Pictures
# 4      10.0  ...                      Funimation             Wit Studio
#
#          Source                             Genres Demographic  \
# 0         Manga          Adventure, Drama, Fantasy     Shounen
# 1         Manga  Action, Adventure, Drama, Fantasy     Shounen
# 2  Visual novel      Drama, Sci-FiSci-Fi, Suspense     Unknown
# 3         Manga       Action, Comedy, Sci-FiSci-Fi     Shounen
# 4         Manga            Action, Drama, Suspense     Shounen
#
#           Duration                          Rating Duration_min Start_year  \
# 0  24 min. per ep.       PG-13 - Teens 13 or older         24.0       2023
# 1  24 min. per ep.  R - 17+ (violence & profanity)         24.0       2009
# 2  24 min. per ep.       PG-13 - Teens 13 or older         24.0       2011
# 3  24 min. per ep.       PG-13 - Teens 13 or older         24.0       2015
# 4  23 min. per ep.  R - 17+ (violence & profanity)         23.0       2019
#
#   new_rating
# 0         PG
# 1          R
# 2         PG
# 3         PG
# 4          R
#
# [5 rows x 25 columns]

# %% [markdown]
# ## 3.8 Clean Demographic Column

# %% [markdown]
# ## 3.9 Duplicates Check
# ## Duplicate rows are a data quality issue that can inflate statistics

# %%
df_clean[df_clean.duplicated()].sum()
# Out:
# Score           0.0
# Popularity        0
# Rank              0
# Members           0
# Description       0
# Synonyms          0
# Japanese          0
# English           0
# Type              0
# Episodes        0.0
# Status            0
# Aired             0
# Premiered         0
# Broadcast         0
# Producers         0
# Licensors         0
# Studios           0
# Source            0
# Genres            0
# Demographic       0
# Duration          0
# Rating            0
# Duration_min    0.0
# Start_year        0
# dtype: object

# %% [markdown]
# ## 4. 📊 Univariate Analysis
#
# ### Why We Do This
# Before comparing variables against each other, we study **each variable on its own**. This reveals:
# - The **distribution shape** (normal? skewed? bimodal?)
# - The **range** and presence of outliers
# - The **frequency** of categories for categorical columns
#
# Every downstream decision (which model to use, how to scale, how to impute) depends on knowing your distributions.

# %% [markdown]
# ## 4.1 Score Distribution
# ## This is the primary target metric — understanding it is job #1

# %% [markdown]
# ## 4.2 Anime Type Distribution

# %% [markdown]
# ## 4.3 Source Material Distribution

# %% [markdown]
# ## 4.4 Genre Distribution
# ## Genres are comma-separated — we need to explode them into individual values

# %% [markdown]
# ## 4.5 Episodes Distribution
# ## Filter to TV shows only and cap at 200 episodes for readability

# %% [markdown]
# ## 4.6 Release Year Trend

# %% [markdown]
# ## 5. 🔗 Bivariate & Multivariate Analysis
#
# ### Why We Do This
# Univariate analysis tells you about **one variable**. Bivariate analysis reveals **relationships** between variables — the most valuable insights for decision-making.
#
# Key questions we'll answer:
# - Does anime type affect score?
# - Do more episodes mean higher or lower scores?
# - Which demographics produce the highest-rated anime?
# - How do score and popularity relate?

# %% [markdown]
# ## 5.1 Score by Anime Type (Box Plot)
# ## Box plots are perfect for comparing distributions across categories

# %% [markdown]
# ## 5.2 Score by Demographic

# %% [markdown]
# ## 5.3 Score vs Popularity (Scatter Plot)
# ## Popularity rank (lower = more popular) vs Score
# ## Using log scale on x-axis because popularity is heavily skewed

# %% [markdown]
# ## 5.4 Top Studios by Average Score
# ## Explode multi-studio entries so each studio gets its own row

# %% [markdown]
# ## 5.5 Rating vs Score

# %% [markdown]
# ## 6. ⚙️ Feature Engineering
#
# ### Why We Do This
# Feature engineering is the process of creating **new columns** from existing ones to make the data more useful for analysis (and later, modeling). Raw data rarely contains the exact information you need — you have to derive it.
#
# This is one of the **highest-leverage skills** a data analyst has. A well-engineered feature can make a simple model outperform a complex one.
#
# We'll create:
# - `Score_Category` — label anime quality tier
# - `Is_Long_Running` — flag for 50+ episode shows
# - `Total_Runtime_Hours` — total viewing time per anime
# - `Decade` — group by decade for historical trends
# - `Genre_Count` — how many genres each anime belongs to
# - `Popularity_Score_Ratio` — normalized popularity vs quality metric
# - `Has_English_Title` — binary flag

# %% [markdown]
# ##6.1 Score Category (Binning)
# ## pd.cut() converts continuous values into labeled buckets
# ## This is called 'discretization' — useful for grouping analysis

# %% [markdown]
# ## 6.2 Long-Running Series Flag

# %% [markdown]
# ## 6.3 Total Runtime in Hours
# ## Multiply episode count × duration per episode

# %% [markdown]
# ## 6.4 Decade Feature

# %% [markdown]
# ## 6.5 Genre Count

# %% [markdown]
# ## 6.6 Has English Title Flag

# %% [markdown]
# ## 6.7 Members Tier (Popularity Tier by Fanbase Size)

# %% [markdown]
# ## 6.8 Visualise Engineered Features

# %% [markdown]
# ## 7. 📐 Correlation Analysis
#
# ### Why We Do This
# Correlation measures the **strength and direction** of the linear relationship between two numeric variables. It's a fast way to screen for which features might predict a target variable (like Score).
#
# - **+1.0** = perfect positive correlation
# - **0.0** = no linear relationship
# - **-1.0** = perfect inverse correlation
#
# ⚠️ **Important:** Correlation ≠ Causation. Always think critically about *why* two variables correlate.

# %% [markdown]
# ## 8. 🔍 Outlier Detection
#
# ### Why We Do This
# Outliers are data points that deviate significantly from the rest. They can:
# - **Corrupt** statistical summaries (mean, std are sensitive to outliers)
# - **Represent genuine rare events** worth investigating (legendary anime, data errors)
# - **Break ML models** if not handled properly
#
# We use two methods:
# 1. **IQR Method** — any point below Q1 - 1.5×IQR or above Q3 + 1.5×IQR is an outlier
# 2. **Z-Score Method** — any point > 3 standard deviations from the mean is an outlier

# %% [markdown]
# ## 8.1 IQR Outlier Detection

# %% [markdown]
# ## 8.2 Z-Score Outlier Detection

# %% [markdown]
# ##8.3 Visualize Outliers with Box Plots

# %% [markdown]
# ## 9. 💡 Key Business Questions
#
# ### Why We Do This
# Pure exploration is useful, but a data analyst's **real job** is answering *specific business questions* with data. This section simulates a stakeholder asking questions and us answering them concisely with visualizations.
#
# Good analysts translate questions into queries, queries into charts, and charts into sentences.

# %% [markdown]
# ## Q1: What are the Top 10 Anime by Score?

# %% [markdown]
# ## Q2: Which genres consistently produce high-scoring anime?
# ## Explode genres → merge with scores → aggregate per genre

# %% [markdown]
# ## Q3: Hidden Gems — High Score but Low Popularity Rank
# ## Popularity rank > 1000 means they're not mainstream, but their score is elite

# %% [markdown]
# ## Q4: Has anime quality improved over the decades?

# %% [markdown]
# ## Q5: Mainstream vs Niche — Do popular anime score higher?

# %% [markdown]
# ## 10. 📋 Summary, Insights & Recommendations
#
# ### Why We Do This
# A data analyst's work only matters if it **drives decisions**. This final section condenses every finding into a stakeholder-ready summary. In a real job, this might become a Confluence page, a slide deck, or an email to your manager.
#
# Great analysts write **concise, opinionated summaries** — not just "here is what I found" but "here is what this means and what you should do about it."
